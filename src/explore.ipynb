# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install plotly
# !pip install seaborn
# !pip install pickle-mixin
# !pip install statsmodels
# !pip install sklearn
# Out:
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (4.34.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib) (1.23.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: plotly in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from plotly) (8.0.1)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: seaborn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: pandas>=0.23 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: scipy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: cycler>=0.10 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pickle-mixin in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.0.2)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: statsmodels in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.23.1)
# Requirement already satisfied: packaging>=21.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: scipy>=1.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.8.1)
# Requirement already satisfied: patsy>=0.5.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pandas>=0.25 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sklearn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.23.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.1.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt  
import seaborn as sns
import plotly.express as px
import statsmodels.api as sm
import pickle
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report

# %%
df_raw = pd.read_csv('https://raw.githubusercontent.com/4GeeksAcademy/decision-tree-project-tutorial/main/diabetes.csv', sep=',')
df_raw
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df_raw.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df_raw.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
df_raw[df_raw['BMI'] == 0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 9              8      125             96              0        0  0.0
# 49             7      105              0              0        0  0.0
# 60             2       84              0              0        0  0.0
# 81             2       74              0              0        0  0.0
# 145            0      102             75             23        0  0.0
# 371            0      118             64             23       89  0.0
# 426            0       94              0              0        0  0.0
# 494            3       80              0              0        0  0.0
# 522            6      114              0              0        0  0.0
# 684            5      136             82              0        0  0.0
# 706           10      115              0              0        0  0.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 9                       0.232   54        1
# 49                      0.305   24        0
# 60                      0.304   21        0
# 81                      0.102   22        0
# 145                     0.572   21        0
# 371                     1.731   21        0
# 426                     0.256   25        0
# 494                     0.174   22        0
# 522                     0.189   26        0
# 684                     0.640   69        0
# 706                     0.261   30        1

# %%
# invalanced data
df_raw["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df_filter = df_raw.copy()
df_filter = df_raw[(df_raw["BMI"] > 0 ) & (df_raw["BloodPressure"] > 0) & (df_raw["Glucose"] > 0)]
df_filter
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [724 rows x 9 columns]

# %%
print('The observations that have BMI, blood pressure or glucose equal to zero are removed.')
print(f'By doing this we lose {len(df_raw)-len(df_filter)} observations.')
# Out:
# The observations that have BMI, blood pressure or glucose equal to zero are removed.
# By doing this we lose 44 observations.

# %%
df = df_filter.copy() 
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [724 rows x 9 columns]

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.134915       0.209668      -0.095683
# Glucose                      0.134915  1.000000       0.223331       0.074381
# BloodPressure                0.209668  0.223331       1.000000       0.011777
# SkinThickness               -0.095683  0.074381       0.011777       1.000000
# Insulin                     -0.080059  0.337896      -0.046856       0.420874
# BMI                          0.012342  0.223276       0.287403       0.401528
# DiabetesPedigreeFunction    -0.025996  0.136630      -0.000075       0.176253
# Age                          0.557066  0.263560       0.324897      -0.128908
# Outcome                      0.224417  0.488384       0.166703       0.092030
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.080059  0.012342                 -0.025996
# Glucose                   0.337896  0.223276                  0.136630
# BloodPressure            -0.046856  0.287403                 -0.000075
# SkinThickness             0.420874  0.401528                  0.176253
# Insulin                   1.000000  0.191831                  0.182656
# BMI                       0.191831  1.000000                  0.154858
# DiabetesPedigreeFunction  0.182656  0.154858                  1.000000
# Age                      -0.049412  0.020835                  0.023098
# Outcome                   0.145488  0.299375                  0.184947
#
#                                Age   Outcome
# Pregnancies               0.557066  0.224417
# Glucose                   0.263560  0.488384
# BloodPressure             0.324897  0.166703
# SkinThickness            -0.128908  0.092030
# Insulin                  -0.049412  0.145488
# BMI                       0.020835  0.299375
# DiabetesPedigreeFunction  0.023098  0.184947
# Age                       1.000000  0.245741
# Outcome                   0.245741  1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=28)

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 534 to 273
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               543 non-null    int64
#  1   Glucose                   543 non-null    int64
#  2   BloodPressure             543 non-null    int64
#  3   SkinThickness             543 non-null    int64
#  4   Insulin                   543 non-null    int64
#  5   BMI                       543 non-null    float64
#  6   DiabetesPedigreeFunction  543 non-null    float64
#  7   Age                       543 non-null    int64
#  8   Outcome                   543 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 42.4 KB

# %%
# Perform univariate analysis - histograms
X_train.hist(figsize=(8,8), alpha=0.5)
plt.show()

# %%
# Perform univariate analysis - boxplots
fig, ax = plt.subplots(2,4, figsize=(8,4))
axs = ax.flatten()
for i in range(len(axs)):
    X_train._get_numeric_data().iloc[:,i].to_frame().boxplot(ax=axs[i])

# %%
# Perform bivariate analysis - numericals
pd.plotting.scatter_matrix(X_train, diagonal='kde', figsize=(8,8), c='Violet')
plt.show()

# %%
df_train.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_37c20_row0_col0, #T_37c20_row1_col1, #T_37c20_row2_col2, #T_37c20_row3_col3, #T_37c20_row4_col4, #T_37c20_row5_col5, #T_37c20_row6_col6, #T_37c20_row7_col7, #T_37c20_row8_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_37c20_row0_col1, #T_37c20_row0_col3, #T_37c20_row4_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_37c20_row0_col2, #T_37c20_row1_col5, #T_37c20_row5_col8 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_37c20_row0_col4, #T_37c20_row4_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_37c20_row0_col5, #T_37c20_row7_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_37c20_row0_col6, #T_37c20_row3_col0, #T_37c20_row3_col1, #T_37c20_row3_col7, #T_37c20_row3_col8, #T_37c20_row4_col2, #T_37c20_row7_col3, #T_37c20_row7_col4, #T_37c20_row7_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_37c20_row0_col7 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_37c20_row0_col8 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_37c20_row1_col0, #T_37c20_row1_col3 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_37c20_row1_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_37c20_row1_col4 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_37c20_row1_col6, #T_37c20_row2_col3 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_37c20_row1_col7 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_37c20_row1_col8, #T_37c20_row2_col7 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_37c20_row2_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_37c20_row2_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_37c20_row2_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_37c20_row2_col5 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_37c20_row2_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_37c20_row2_col8 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_37c20_row3_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_37c20_row3_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_37c20_row3_col5 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_37c20_row3_col6, #T_37c20_row6_col8 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_37c20_row4_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_37c20_row4_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_37c20_row4_col5, #T_37c20_row6_col4 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_37c20_row4_col6 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_37c20_row4_col8, #T_37c20_row6_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_37c20_row5_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_37c20_row5_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_37c20_row5_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_37c20_row5_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_37c20_row5_col4 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_37c20_row5_col6, #T_37c20_row6_col7, #T_37c20_row7_col8 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_37c20_row5_col7 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_37c20_row6_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_37c20_row6_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_37c20_row6_col3, #T_37c20_row8_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_37c20_row6_col5 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_37c20_row7_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_37c20_row7_col1 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_37c20_row7_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_37c20_row8_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_37c20_row8_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_37c20_row8_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_37c20_row8_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_37c20_row8_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_37c20_row8_col6 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_37c20_row8_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# </style>
# <table id="T_37c20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37c20_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_37c20_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_37c20_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_37c20_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_37c20_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_37c20_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_37c20_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_37c20_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_37c20_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37c20_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_37c20_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_37c20_row0_col1" class="data row0 col1" >0.128695</td>
#       <td id="T_37c20_row0_col2" class="data row0 col2" >0.203663</td>
#       <td id="T_37c20_row0_col3" class="data row0 col3" >-0.059651</td>
#       <td id="T_37c20_row0_col4" class="data row0 col4" >-0.041003</td>
#       <td id="T_37c20_row0_col5" class="data row0 col5" >-0.007470</td>
#       <td id="T_37c20_row0_col6" class="data row0 col6" >0.019356</td>
#       <td id="T_37c20_row0_col7" class="data row0 col7" >0.562590</td>
#       <td id="T_37c20_row0_col8" class="data row0 col8" >0.214185</td>
#     </tr>
#     <tr>
#       <th id="T_37c20_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_37c20_row1_col0" class="data row1 col0" >0.128695</td>
#       <td id="T_37c20_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_37c20_row1_col2" class="data row1 col2" >0.228245</td>
#       <td id="T_37c20_row1_col3" class="data row1 col3" >0.069994</td>
#       <td id="T_37c20_row1_col4" class="data row1 col4" >0.313630</td>
#       <td id="T_37c20_row1_col5" class="data row1 col5" >0.214476</td>
#       <td id="T_37c20_row1_col6" class="data row1 col6" >0.126815</td>
#       <td id="T_37c20_row1_col7" class="data row1 col7" >0.241120</td>
#       <td id="T_37c20_row1_col8" class="data row1 col8" >0.476305</td>
#     </tr>
#     <tr>
#       <th id="T_37c20_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_37c20_row2_col0" class="data row2 col0" >0.203663</td>
#       <td id="T_37c20_row2_col1" class="data row2 col1" >0.228245</td>
#       <td id="T_37c20_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_37c20_row2_col3" class="data row2 col3" >-0.003589</td>
#       <td id="T_37c20_row2_col4" class="data row2 col4" >-0.029131</td>
#       <td id="T_37c20_row2_col5" class="data row2 col5" >0.276175</td>
#       <td id="T_37c20_row2_col6" class="data row2 col6" >0.028567</td>
#       <td id="T_37c20_row2_col7" class="data row2 col7" >0.340978</td>
#       <td id="T_37c20_row2_col8" class="data row2 col8" >0.182279</td>
#     </tr>
#     <tr>
#       <th id="T_37c20_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_37c20_row3_col0" class="data row3 col0" >-0.059651</td>
#       <td id="T_37c20_row3_col1" class="data row3 col1" >0.069994</td>
#       <td id="T_37c20_row3_col2" class="data row3 col2" >-0.003589</td>
#       <td id="T_37c20_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_37c20_row3_col4" class="data row3 col4" >0.434014</td>
#       <td id="T_37c20_row3_col5" class="data row3 col5" >0.378657</td>
#       <td id="T_37c20_row3_col6" class="data row3 col6" >0.160786</td>
#       <td id="T_37c20_row3_col7" class="data row3 col7" >-0.131113</td>
#       <td id="T_37c20_row3_col8" class="data row3 col8" >0.103272</td>
#     </tr

# %%
sns.boxplot(x="Outcome", y="Glucose", data=df_train)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Glucose'>

# %%
sns.boxplot(x="Outcome", y="BMI", data=df_train)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %% [markdown]
# # Model

# %%
model = DecisionTreeClassifier(criterion='entropy',random_state=0)
model.fit(X_train, y_train)

print('Accuracy model - train set:', model.score(X_train, y_train))
print('Accuracy model - test set:', model.score(X_test, y_test))
# Out:
# Accuracy model - train set: 1.0
# Accuracy model - test set: 0.7182320441988951

# %%
clf_pred = model.predict(X_test)

# %%
cm = confusion_matrix(y_test, clf_pred, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
display_labels=model.classes_)
disp.plot()

plt.show()

# %%
print('Classification report - Model')
print('################################')
print(classification_report(y_test,clf_pred))
# Out:
# Classification report - Model
# ################################
#               precision    recall  f1-score   support
#
#            0       0.81      0.76      0.78       120
#            1       0.57      0.64      0.60        61
#
#     accuracy                           0.72       181
#    macro avg       0.69      0.70      0.69       181
# weighted avg       0.73      0.72      0.72       181

# %%
plt.figure(figsize=(10,8))
tree.plot_tree(model)
plt.show()

# %%
# hiperparams
params = {'criterion': ['gini', 'entropy'], 'max_depth': range(1,10), 'min_samples_split':range(1,10), 'min_samples_leaf': range(1,5)}
grid = GridSearchCV(DecisionTreeClassifier(random_state=0), params, verbose=1, n_jobs=-1,cv=3)
grid.fit(X_train, y_train)
print('Best hyperparameters selected by grid search and cross validation')
print('--------------------------------------------------------------')
grid.best_params_
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# Best hyperparameters selected by grid search and cross validation
# --------------------------------------------------------------
# /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 216 fits failed out of a total of 1944.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 216 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 969, in fit
#     super().fit(
#   File "/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/sklearn/tree/_classes.py", line 265, in fit
#     check_scalar(
#   File "/home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/sklearn/utils/validation.py", line 1480, in check_scalar
#     raise ValueError(
# ValueError: min_samples_split == 1, must be >= 2.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan 0.68324125 0.68324125 0.68324125 0.68324125 0.68324125
#  0.68324125 0.68324125 0.68324125        nan 0.68324125 0.68324125
#  0.68324125 0.68324125 0.68324125 0.68324125 0.68324125 0.68324125
#         nan 0.68324125 0.68324125 0.68324125 0.68324125 0.68324125
#  0.68324125 0.68324125 0.68324125        nan 0.68324125 0.68324125
#  0.68324125 0.68324125 0.68324125 0.68324125 0.68324125 0.68324125
#         nan 0.71823204 0.71823204 0.71823204 0.71823204 0.71823204
#  0.71823204 0.71823204 0.71823204        nan 0.71823204 0.71823204
#  0.71823204 0.71823204 0.71823204 0.71823204 0.71823204 0.71823204
#         nan 0.71823204 0.71823204 0.71823204 0.71823204 0.71823204
#  0.71823204 0.71823204 0.71823204        nan 0.71823204 0.71823204
#  0.71823204 0.71823204 0.71823204 0.71823204 0.71823204 0.71823204
#         nan 0.6961326  0.6961326  0.6961326  0.6961326  0.6961326
#  0.6961326  0.6961326  0.6961326         nan 0.6961326  0.6961326
#  0.6961326  0.6961326  0.6961326  0.6961326  0.6961326  0.6961326
#         nan 0.6961326  0.6961326  0.6961326  0.6961326  0.6961326
#  0.6961326  0.6961326  0.6961326         nan 0.69797422 0.69797422
#  0.69797422 0.69797422 0.69797422 0.69797422 0.69797422 0.69797422
#         nan 0.75690608 0.76611418 0.76611418 0.7587477  0.7587477
#  0.7587477  0.7587477  0.7587477         nan 0.75322284 0.75322284
#  0.75322284 0.75322284 0.75322284 0.75322284 0.75322284 0.75322284
#         nan 0.75138122 0.75138122 0.75138122 0.75138122 0.75138122
#  0.75138122 0.75138122 0.75138122        nan 0.75322284 0.75322284
#  0.75322284 0.75322284 0.75322284 0.75322284 0.75322284 0.75322284
#         nan 0.75322284 0.75506446 0.75690608 0.74953959 0.74953959
#  0.74953959 0.74953959 0.74953959        nan 0.73480663 0.73480663
#  0.73480663 0.73480663 0.73480663 0.74033149 0.74033149 0.74033149
#         nan 0.73664825 0.73664825 0.73664825 0.73664825 0.73664825
#  0.74217311 0.74217311 0.74217311        nan 0.74769797 0.74769797
#  0.74769797 0.74769797 0.74769797 0.74769797 0.74769797 0.74769797
#         nan 0.74033149 0.74033149 0.74033149 0.74217311 0.74401473
#  0.74953959 0.74953959 0.74953959        nan 0.73664825 0.73664825
#  0.73664825 0.73480663 0.73296501 0.73664825 0.73848987 0.74033149
#         nan 0.73848987 0.73848987 0.73848987 0.73848987 0.73848987
#  0.75322284 0.75322284 0.74953959        nan 0.74953959 0.74953959
#  0.74953959 0.74953959 0.74953959 0.74953959 0.74953959 0.74953959
#         nan 0.72744015 0.72928177 0.72928177 0.72744015 0.73296501
#  0.73296501 0.73296501 0.73296501        nan 0.7145488  0.7145488
#  0.7145488  0.7145488  0.72191529 0.72375691 0.72375691 0.72928177
#         nan 0.72559853 0.72559853 0.72559853 0.72559853 0.72559853
#  0.73848987 0.74217311 0.73480663        nan 0.70902394 0.70902394
#  0.70902394 0.70902394 0.70902394 0.70902394 0.70902394 0.72007366
#         nan 0.71639042 0.72007366 0.72559853 0.71823204 0.71823204
#  0.72191529 0.72191529 0.72375691        nan 0.70902394 0.70902394
#  0.70902394 0.70349908 0.7053407  0.7145488  0.72007366 0.71639042
#         nan 0.7145488  0.7145488  0.7145488  0.7145488  0.7145488
#  0.72375691 0.72375691 0.72928177        nan 0.71270718 0.71270718
#  0.71270718 0.71270718 0.71270718 0.71270718 0.71270718 0.71823204
#         nan 0.71086556 0.70902394 0.70902394 0.71270718 0.71823204
#  0.71823204 0.72191529 0.72375691        nan 0.7145488  0.7145488
#  0.7145488  0.70349908 0.6961326  0.70349908 0.71270718 0.71639042
#         nan 0.71270718 0.71270718 0.71270718 0.71270718 0.71270718
#  0.72007366 0.72191529 0.73112339        nan 0.7145488  0.7145488
#  0.7145488  0.7145488  0.7145488  0.7145488  0.7145488  0.72007366
#         nan 0.67219153 0.67219153 0.67219153 0.67219153 0.67219153
#  0.67219153 0.67219153 0.67219153        nan 0.67219153 0.67219153
#  0.67219153 0.67219153 0.67219153 0.67219153 0.67219153 0.67219153
#         nan 0.67219153 0.67219153 0.67219153 0.67219153 0.67219153
#  0.67219153 0.67219153 0.67219153        nan 0.67219153 0.67219153
#  0.67219153 0.67219153 0.67219153 0.67219153 0.67219153 0.67219153
#         nan 0.7145488  0.7145488  0.7145488  0.7145488  0.7145488
#  0.7145488  0.7145488  0.7145488         nan 0.7145488  0.7145488
#  0.7145488  0.7145488  0.7145488  0.7145488  0.7145488  0.7145488
#         nan 0.7145488  0.7145488  0.7145488  0.7145488  0.7145488
#  0.7145488  0.7145488  0.7145488         nan 0.7145488  0.7145488
#  0.7145488  0.7145488  0.7145488  0.7145488  0.7145488  0.7145488
#         nan 0.69429098 0.69429098 0.69429098 0.69429098 0.69429098
#  0.69429098 0.69429098 0.69429098        nan 0.69429098 0.69429098
#  0.69429098 0.69429098 0.69429098 0.69429098 0.69429098 0.69429098
#         nan 0.69429098 0.69429098 0.69429098 0.69429098 0.69429098
#  0.69429098 0.69429098 0.69429098        nan 0.6961326  0.6961326
#  0.6961326  0.6961326  0.6961326  0.6961326  0.6961326  0.6961326
#         nan 0.74953959 0.75690608 0.75690608 0.75138122 0.75138122
#  0.75138122 0.75138122 0.75138122        nan 0.75322284 0.75322284
#  0.75322284 0.75322284 0.75322284 0.75322284 0.75322284 0.75322284
#         nan 0.75322284 0.75322284 0.75322284 0.75322284 0.75322284
#  0.75322284 0.75322284 0.75322284        nan 0.75506446 0.75506446
#  0.75506446 0.75506446 0.75506446 0.75506446 0.75506446 0.75506446
#         nan 0.74033149 0.74217311 0.74217311 0.73664825 0.73664825
#  0.73664825 0.73664825 0.73664825        nan 0.74033149 0.74033149
#  0.74033149 0.74033149 0.73848987 0.73848987 0.73848987 0.73848987
#         nan 0.74033149 0.74033149 0.74033149 0.74033149 0.74033149
#  0.74033149 0.74033149 0.74033149        nan 0.74033149 0.74033149
#  0.74033149 0.74033149 0.74033149 0.74033149 0.74033149 0.74033149
#         nan 0.7145488  0.72007366 0.72007366 0.72007366 0.72007366
#  0.72007366 0.72744015 0.72744015        nan 0.72375691 0.72375691
#  0.72375691 0.72375691 0.72375691 0.72375691 0.72928177 0.72744015
#         nan 0.72928177 0.72928177 0.72928177 0.72928177 0.72928177
#  0.72928177 0.73296501 0.73296501        nan 0.73664825 0.73664825
#  0.73664825 0.73664825 0.73664825 0.73664825 0.73664825 0.73296501
#         nan 0.72191529 0.72007366 0.7145488  0.71639042 0.7145488
#  0.7145488  0.72559853 0.72191529        nan 0.72007366 0.72007366
#  0.72007366 0.72007366 0.71823204 0.71639042 0.72191529 0.72375691
#         nan 0.72559853 0.72559853 0.72559853 0.72559853 0.72559853
#  0.72559853 0.72559853 0.72375691        nan 0.72375691 0.72375691
#  0.72375691 0.72375691 0.72375691 0.72375691 0.72375691 0.72007366
#         nan 0.70902394 0.70902394 0.7053407  0.71086556 0.71086556
#  0.70718232 0.7145488  0.71270718        nan 0.72007366 0.72007366
#  0.72007366 0.72191529 0.71639042 0.71086556 0.72191529 0.72007366
#         nan 0.71270718 0.71270718 0.71270718 0.71270718 0.71270718
#  0.70902394 0.7145488  0.71270718        nan 0.72007366 0.72007366
#  0.72007366 0.72007366 0.72007366 0.72007366 0.72007366 0.72007366
#         nan 0.72007366 0.72375691 0.71086556 0.70718232 0.71086556
#  0.70902394 0.71823204 0.71270718        nan 0.7145488  0.7145488
#  0.7145488  0.71086556 0.71086556 0.7145488  0.72007366 0.71823204
#         nan 0.71639042 0.71639042 0.71639042 0.71639042 0.71639042
#  0.7145488  0.71639042 0.71270718        nan 0.71270718 0.71270718
#  0.71270718 0.71270718 0.71270718 0.71270718 0.71270718 0.70718232]
#   warnings.warn(
# {'criterion': 'gini',
#  'max_depth': 4,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3}

# %%
model_cv = grid.best_estimator_
model_cv
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_split=3, random_state=0)

# %%
print('Accuracy of tree selected by CV in train set:',grid.score(X_train, y_train))
# Out:
# Accuracy of tree selected by CV in train set: 0.8250460405156538

# %%
y_pred = model_cv.predict(X_test)
print('Accuracy of tree selected by CV in test set:',np.mean(y_test==y_pred))

print('Accuracy of tree selected by CV in test set:',grid.score(X_test, y_test))
# Out:
# Accuracy of tree selected by CV in test set: 0.7237569060773481
# Accuracy of tree selected by CV in test set: 0.7237569060773481

# %%
cm = confusion_matrix(y_test, y_pred, labels=grid.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
display_labels=grid.classes_)
disp.plot()

plt.show()

# %%
print('Classification report - Model 2')
print('---------------------------------')
print(classification_report(y_test,y_pred))
# Out:
# Classification report - Model 2
# ---------------------------------
#               precision    recall  f1-score   support
#
#            0       0.78      0.82      0.80       120
#            1       0.60      0.54      0.57        61
#
#     accuracy                           0.72       181
#    macro avg       0.69      0.68      0.68       181
# weighted avg       0.72      0.72      0.72       181

# %%
plt.figure(figsize=(10,8))
tree.plot_tree(model_cv)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, random_state=0)
rfc.fit(X_train, y_train)
print('Accuracy RFC:', rfc.score(X_test, y_test))
# Out:
# Accuracy RFC: 0.7679558011049724

# %%
param_grid = [{'max_depth': [8, 12, 16], 
         'min_samples_split': [12, 16, 20], 
         'criterion': ['gini', 'entropy']}]

rfc=RandomForestClassifier(random_state=1107)
grid_rfc=GridSearchCV(estimator=rfc,param_grid=param_grid, cv=5, n_jobs=-1,verbose=2)
grid_rfc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=12; total time=   0.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=12; total time=   0.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   0.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=12; total time=   0.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=16; total time=   0.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=12; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=12; total time=   0.5s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END ..criterion=gini, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=20; total time=   0.5s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=20; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=20; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=20; total time=   0.6s
# [CV] END .criterion=gini, max_depth=12, min_samples_split=20; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=12; total time=   0.5s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=12; total time=   0.5s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=12; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=20; total time=   0.5s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=16; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=20; total time=   0.5s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=20; total time=   0.5s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=20; total time=   0.6s
# [CV] END .criterion=gini, max_depth=16, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=12; total time=   0.7s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=16; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   0.5s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=12; total time=   0.5s
# [CV] END criterion=entropy, max_depth=8, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=12; total time=   0.7s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=20; total time=   0.5s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=20; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=20; total time=   0.6s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=20; total time=   0.7s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=12; total time=   0.6s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=12; total time=   0.7s
# [CV] END criterion=entropy, max_depth=12, min_samples_split=16; total time=   0.8s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=12; total time=   0.7s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=20; total time=   0.4s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=20; total time=   0.4s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=20; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=16; total time=   0.5s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=20; total time=   0.4s
# [CV] END criterion=entropy, max_depth=16, min_samples_split=20; total time=   0.4s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1107),
#              n_jobs=-1,
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': [8, 12, 16],
#                           'min_samples_split': [12, 16, 20]}],
#              verbose=2)

# %%
print('Best parameters:', grid_rfc.best_params_)
# Out:
# Best parameters: {'criterion': 'gini', 'max_depth': 8, 'min_samples_split': 20}

# %%
model_rfc_cv = grid_rfc.best_estimator_

# %%
y_pred_rfc_cv = model_rfc_cv.predict(X_test)
print('Accuracy of random forest selected by CV in test set (grid search):',grid_rfc.score(X_test, y_test))
# Out:
# Accuracy of random forest selected by CV in test set (grid search): 0.7900552486187845

# %%
importance = model_rfc_cv.feature_importances_
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))

plt.figure(figsize=(30,5))
columns = X.columns
sns.barplot(columns, importance)
plt.title('Feature importance')
plt.show()
# Out:
# Feature: 0, Score: 0.06858
# Feature: 1, Score: 0.30694
# Feature: 2, Score: 0.06693
# Feature: 3, Score: 0.05409
# Feature: 4, Score: 0.06689
# Feature: 5, Score: 0.16852
# Feature: 6, Score: 0.11918
# Feature: 7, Score: 0.14886
# /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
filename = '../models/final_model.sav'
pickle.dump(model_rfc_cv, open(filename, 'wb'))
